# %%
print(10+True + True + False)  # true means 1 and false means 0 so the output will be 10+1+1+0=12
print(False + False + True + True + True)  # false means 0 and true means 1 so the output will be 0+0+1+1+1=3
# Out:
# 12
# 3

# %%
print(5 // 2) #// is called the floor division operator.
print(-5 // 2)
print(5 % 2)
# Out:
# 2
# -3
# 1

# %%
print(2 ** 3 ** 2) # 2 ** (3 ** 2) -->2 ** 9 ---> 512
print("5" + "5")
print("5" * 3)
# Out:
# 512
# 55
# 555

# %%
#truth value (truthy or falsy), not the meaning of the content.
# Empty string "" → False
# Any non-empty string → True

print(bool("False"))
print(bool(0), bool(-1))
# 0 → False
# Any other number → True
print(bool([]), bool([0]), bool([False]), bool([None]))
# Out:
# True
# False True
# False True True True

# %%
x = "Python"
print(x[-1])

print(x[::-1])
# Out:
# n
# nohtyP

# %%
a = "hello"
b = "hello"

print(a is b)
print(a == b)
# Out:
# True
# True

# %%
x = [1,2,3]
y = x #This does not create a new list.   -->It copies the reference.

y.append(4)

print(x)
# Out:
# [1, 2, 3, 4]

# %%
print(id(x))
print(id(y))
print(x is y) #True because both x and y point to the same list object in memory.
print(x == y) #True because both x and y have the same content.
print("""
x ───────┐
         │
         ▼
    [1, 2, 3, 4]
         ▲
         │
y ───────┘
      
""")
cc=x.copy() #This creates a new list object with the same content as x.   -->It copies the content.
# Out:
# 1906770414912
# 1906770414912
# True
# True
#
# x ───────┐
#          │
#          ▼
#     [1, 2, 3, 4]
#          ▲
#          │
# y ───────┘

# %%
x = [1,2,3]
y = x.copy()

y.append(4)

print(x)
print(y)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
for i in range(5):
    pass

print(i)
# Out:
# 4

# %%
for i in range(3):
    print(i)
else:
    print("Done")
# Out:
# 0
# 1
# 2
# Done

# %%
for i in range(5):
    if i == 3:
        break
else:
    print("Completed")

# %%
a = [[0]*3]*3

a[0][0] = 5

print(a)
# Out:
# [[5, 0, 0], [5, 0, 0], [5, 0, 0]]

# %%
a = [1,2]
b = [1,2]

print(a == b)
print(a is b)
# == → checks value
# is → checks memory location

# %%
a = (1)

b = (1,)

print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
print(0 or 5)
print(10 and 20)
print(1 < 2 < 3)
print(1 < 2 and 2 < 3)
print(True and True)
# Out:
# 5
# 20
# True
# True
# True

# %%
print(0.1 + 0.2) #Floating point issue
# Out:
# 0.30000000000000004

# %%
x = 10
y = 2.0

print(x + y)
print(type(x + y))
print(22+ True)
# Out:
# 12.0
# <class 'float'>
# 23

# %%
x = "10"
y = 5

try:
    # 1. Try to run the code that might cause an error
    print(x + y)
    
except TypeError as e:
    # 2. If an error occurs, this block executes
    print("An error occurred:", e)
# Out:
# An error occurred: can only concatenate str (not "int") to str

# %%
print(bool([]))
print(bool({}))
print(bool(""))
print(bool(0))

print(bool([0])) #Because they contain some value. Non Empty Values
print(bool("False"))
print(bool(-10))
# Out:
# False
# False
# False
# False
# True
# True
# True

# %%
x = [1,2,3]
y = (1,2,3)

print(type(x))
print(type(y))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
x = {1,2,2,3,3,3}

print(x)  #removes duplicates and returns a set with unique elements.
x = None

print(type(x))
# Out:
# {1, 2, 3}
# <class 'NoneType'>

# %%
x = [[1,2]] * 3

x[0][0] = 100

print(x)
# Out:
# [[100, 2], [100, 2], [100, 2]]

# %%
a = [1,2,3]

print(a * 3)  #This will repeat the list three times, resulting in [1, 2, 3, 1, 2, 3, 1, 2, 3].
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a = (10,) #This is a tuple with a single element. The comma is necessary to distinguish it from a regular integer enclosed in parentheses.
print(type(a))

a = ([1,2],3)
a[0].append(10)
print(a)
# Out:
# <class 'tuple'>
# ([1, 2, 10], 3)

# %%
a = {
    "name":"Ram",
    "name":"Sam"
}

print(a)
# Out:
# {'name': 'Sam'}
